# %% [markdown]
# # Exercise 6
#
# In Statistical Mechanics the one-dimensional (1D) Ising Model is exactly resoluble. The Hamiltonian for a system of N spins with nearest neighbors interaction is given by (in the following I will assume units such that $\mu_B=1$ and $k_B=1$):
#
# $$
# H =
# -J\sum_{i=1}^N s_i s_{i+1}
# -\frac{h}{2}\sum_{i=1}^N (s_i + s_{i+1})
# $$
#
# where $\{ s_i \}_{i=1,N}$ are spin variables taking values in $\{-1;1\}$, $J>0$ (ferromagnetic model),and with the assumption $s_{N+1} = s_{1}$.
#
# The partition function for $N$ spins, $Z$, can be exactly computed and it turns out to be:
#
# $$
# Z=\sum_{\{ s_i \}} \exp \left( -\beta H\right) = \lambda_1^N + \lambda_2^N
# $$
#
# where
# $\lambda_{1,2} =
# e^{\beta J}
# \cosh (\beta h) \pm \left[ e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J) \right]^{1/2}$,
# and where $\beta=\frac{1}{k_b T} = \frac{1}{T}$.
# Once the partition function has been computed, the Helmholtz free energy is readly obtained as $A = -k_B T \ln Z$. All the thermodynamic quantities of interest can be deduced from $A$ or, equivalently, from $Z$:
#
# - the **Internal Energy** per spin (with $h=0$):
#
# $$
# \frac{U(N,T)}{N} = \frac{\langle H \rangle}{N}
# = \frac{1}{N} \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}
# = -\frac{1}{N}\frac{\partial \ln Z}{\partial \beta}
# \underset{h=0}= -J \tanh (\beta J) \Biggl( \frac{1 + \tanh^{N-2} (\beta J)}{1+\tanh^N (\beta J)} \Biggl)
# $$
#
# - the **Heat Capacity** (with $h=0$):
#
# $$
# C(N,T) = \frac{\partial U(N,T)}{\partial T}
# = \frac{\partial \beta}{\partial T}\frac{\partial U}{\partial \beta}
# = -k_B\beta^2 \frac{\partial}{\partial \beta} \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z} \right] = \\
# = -k_B\beta^2 \left[ -\sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} + \sum_{\{ s_i \}} H \exp \left( -\beta H\right)\frac{\partial Z^{-1}}{\partial \beta} \right] = \\
# = k_B\beta^2 \left\{ \sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} + \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}\right]\frac{1}{Z}\frac{\partial Z}{\partial \beta} \right\} =\\
# = k_B\beta^2 \left\{ \sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} - \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}\right]^2 \right\} =
# k_B\beta^2 \left(\langle H^2 \rangle -\langle H \rangle^2 \right)
# $$
#
# $$
# \frac{C(N,T)}{N} = \frac{1}{N}\frac{\partial U(N,T)}{\partial T} =\\
# \underset{h=0}=
# k_B (\beta J)^2 \left\{ 1+\tanh^N (\beta J)+(N-1)\tanh^2 (\beta J)+(N-1)\frac{\tanh^{N-2} (\beta J)}{1+\tanh^N (\beta J)}
# - N \left[ \frac{\tanh (\beta J) + \tanh^{N-1} (\beta J)}{1+\tanh^N (\beta J)} \right]^2 \right\}
# $$
#
# - The **magnetization** (with $h \not= 0$):
#
# Note that with $h=0$ the magnetization $M(N,T,h=0)=\langle \sum_{i=1,N}s_i \rangle =0$ because in 1D we cannot have a (ferromagnetic) phase transition in absence of an external magnetic field.
#
# $$
# M(N,T,h) = -\frac{\partial A}{\partial h} = k_B T \frac{\partial \ln Z}{\partial h} =
# \frac{1}{\beta} \frac{1}{Z}\frac{\partial}{\partial h}\sum_{\{ s_i \}} \exp \left( -\beta H\right) = \sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z} = \left\langle \sum_{i=1,N}s_i \right\rangle
# $$
#
# The exact formula from $M(N,T,h) = k_B T \dfrac{\partial \ln Z}{\partial h}$ is:
# $$
# \frac{M(N,T,h)}{N}=\frac{e^{\beta J}\; \sinh(\beta h)}{Z} \; \Bigl[\lambda_1^{N-1}\cdot \Bigl(1+\frac{e^{\beta J}\; \cosh(\beta h)}{\sqrt{e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J)}}\Bigr) + \lambda_2^{N-1}\cdot \Bigl(1-\frac{e^{\beta J}\; \cosh(\beta h)}{\sqrt{e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J)}}\Bigr)\Bigr]
# $$
#
# - The **magnetic susceptibility** (with $h=0$):
#
# $$
# \chi(N,T) = \frac{\partial M}{\partial h} =
# \frac{\partial}{\partial h}\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z} =\\
# = \beta\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right]^2 \frac{\exp \left( -\beta H\right)}{Z}
# -\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z}
# \frac{1}{Z}\frac{\partial Z}{\partial h} =
# \beta \left[ \left\langle \left( \sum_{i=1,N}s_i \right)^2 \right\rangle - \left\langle \sum_{i=1,N}s_i \right\rangle^2 \right] = \\
# \underset{h=0}= \beta \left[ \left\langle \left( \sum_{i=1,N}s_i \right)^2 \right\rangle \right] = \beta e^{2\beta J} \Biggl( \frac{1-\tanh^N (\beta J)}{1+\tanh^N (\beta J)} \Biggl)
# $$

# %% [markdown]
# ### Exercise 06.1
#
# Complete the C++ code to simulate 1D Ising model (It is available on the Ariel web site of this Laboratory) with
# - the Metropolis sampling algorithm and
# - the Gibbs sampling algorithm
#
# to sample the Boltzmann's weight $p(\{ s_i \}) = \exp(-\beta H)/Z$,
# adding also the possibility to restart from a previous spin configuration.
#
# The code already computes the internal energy: $U(N,T) = \langle H \rangle$. Add the calculation of $C(N,T)$, $\chi(N,T)$, $M(N,T,h)$ and compute:
# 1. $U(N,T) = \langle H \rangle_{h=0}$
# 2. $C(N,T) = k_B \beta^2 (\langle H^2 \rangle_{h=0}-\langle H \rangle_{h=0}^2)$
# 3. $\chi(N,T) = \beta \langle (\sum_{i=1,N}s_i)^2 \rangle_{h=0}$
# 4. $M(N,T,h=0.02)= \langle \sum_{i=1,N}s_i \rangle_{h=0.02}$
#
# as a function of $T$ in the range $\left[0.5;2.0\right]$ for a system of $N=50$ spins with $J=1$.
#
# As usual, use data blocking and give an estimate of the statistical uncertainties.

# %% [markdown]
# - Show pictures of your estimations of $U(N,T)$, $C(N,T)$, $\chi(N,T)$, $M(N,T,h=0.02)$ and their uncertainties obtained with a large number of *MC steps* (e.g. $M\ge 10^5$) compared with the exact curves. In the same picture show your results obtained with both sampling methods, Metropolis and Gibbs.
#
# A Monte Carlo step will consist in trying to flip one time all the spins of the system. Do not forget to equilibrate your simulations and to use blocking average with blocks large enough.

# %% [markdown]
# # Equilibration
#
# First of all we need to understand the typical time in which the system rearranges itself from an initial random configuration to the a configuration which is compatible to the physics of the system given a fixed temperature.
#
# In order to do so I simulated the 50 X 50 Ising spin model at high temperature with two different seeds for both the algorithms, namely Metropolis and Gibbs.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# We start in a high temperature limit with two random seeds and two different configurations and see how much time it takes to converge

# %%
fig = plt.figure(figsize=(12,4))
fig.suptitle('Equilibration', fontsize=20)

plt.subplot(1,2,1)
ene = np.loadtxt('./6.1/output.mag_gibbs_single.0', usecols=(0, 2))
plt.plot(ene[:,1],label='$T=+\infty$, Seed 1', c='tab:green')
ene = np.loadtxt('./6.1/output.mag_gibbs_double.0', usecols=(0, 2))
plt.plot(ene[:,1],label='$T=+\infty$, Seed 2', c='tab:orange')
plt.xlabel('Step', fontsize=14)
plt.axhline(0, c='red', label='expected', ls='--', lw=1)
plt.ylabel('M', fontsize=14)
plt.title('Gibbs', fontsize=16)
plt.legend(fontsize=14, loc='lower right')

plt.subplot(1,2,2)
ene = np.loadtxt('./6.1/output.mag_metro_single.0', usecols=(0, 2))
plt.plot(ene[:,1],label='$T=+\infty$, Seed 1', c='tab:green')
ene = np.loadtxt('./6.1/output.mag_metro_double.0', usecols=(0, 2))
plt.plot(ene[:,1],label='$T=+\infty$, Seed 2', c='tab:orange')
plt.xlabel('Step', fontsize=14)
plt.axhline(0, c='red', label='expected', ls='--', lw=1)
plt.legend(fontsize=14)
plt.ylabel('M', fontsize=14)
plt.title('Metropolis', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# As quite clear from above, the equilibration could be considered as complete right after $10^4$ steps. Hence, I decided to add in the original code the fuction:
# ```cpp
# void Thermalize (void){
#   for (int istep=1; istep<=nstep; ++istep){
#     Move(metro);
#   }
# }
# ```
#
# Which simply 'evolves' the system for the required number of steps without affecting the blocking average mechanism.

# %% [markdown]
# ### Simulation
#
# I decided to carry out all the simulations with $100$ blocks and $10^4$ throws in each block for each fixed temperature. For each quantity I decided to sample 58 points evenly spaced of temperature, ranging from $0.2$ to $3.0$.
#
# ### How to use my code
#
# To launch a simulation, just run `./simulation.sh`. This simple bash script contains:
#
# ``` bash
# #!/bin/bash
#
# # check if the correct number of arguments is provided
# if [ "$#" -ne 2 ]; then
#     echo "Usage: $0 [U|M|C|CHI] [Metro|Gibbs]"
#     exit 1
# fi
#
# python params_manager.py "$1" "$2"
# ./simulationTemperatures.sh "$1" "$2"
# ```
#
# Where `parameters_manager.py` takes care of changing the input parameters in order to simulate the system at different temperatures (and external field in the magnitude case).
# Likewise, `simulationTemperatures.sh` is a simple bash routine that runs the simulation in a for loop accepting the input files created with the previous python script.
# The program accepts as command line inputs the quantity you want to simulate ([U|M|C|CHI]) and the algorithm you want to use ([Metro|Gibbs]) and builds a folder with all the inputs given and the results obtained.

# %% [markdown]
# ### Internal energy

# %%
import glob
import re
fig = plt.figure(figsize=(12,5))
fig.suptitle('$U$, internal energy', fontsize=20)

plt.subplot(1,2,1)

T = np.linspace(0.2,3,num=58)
beta = 1/T
J = 1.0
Ns = 50
th = np.tanh(J/T)
thN= th**Ns
ch = 1/th
e = -J*( th + ch*thN )/( 1 + thN )
plt.plot(T, e, label='Theory')
plt.title('Simulation', fontsize=16)
plt.xlabel('T', fontsize=14)
plt.ylabel('U/N', fontsize=14)

# Get a list of all the files that match the pattern temp*.dat in the folder containg this first simulation files
file_list = glob.glob("6.1/U/results/Metro/output.ene_*.dat")
file_list2 = glob.glob("6.1/U/results/Gibbs/output.ene_*.dat")

def extract_number(filename):
    return float(re.findall(r'\d+\.\d+', filename)[-1])

sorted_list = sorted(file_list, key=extract_number)
sorted_list2 = sorted(file_list2, key=extract_number)

results = []
uncertainties = []
temp = []

results2 = []
uncertainties2 = []
temp2=[]

for file in sorted_list:
    ene = np.loadtxt(file, usecols=(0, 2))
    err = np.loadtxt(file, usecols=(0, 3))
    results.append(ene[:,1][-1])
    uncertainties.append(err[:,1][-1])
    temp.append(float(file.split('_')[1].replace('.dat','')))
    
for file in sorted_list2:
    ene = np.loadtxt(file, usecols=(0, 2))
    err = np.loadtxt(file, usecols=(0, 3))
    results2.append(ene[:,1][-1])
    uncertainties2.append(err[:,1][-1])
    temp2.append(float(file.split('_')[1].replace('.dat','')))

    
plt.errorbar(temp, results, yerr=uncertainties,ls='--', elinewidth=1.5, marker='o', ms=4, mec='black', mew=0.5, label='Metropolis')
plt.errorbar(temp2, results2, yerr=uncertainties2,ls='--', elinewidth=1.5, marker='o', ms=4, mec='black', mew=0.5, label='Gibbs')

plt.legend(fontsize=14)

plt.subplot(2,2, 2)
plt.plot(T,abs(results-e), c='tab:orange', label = 'Metropolis')
plt.plot(T,uncertainties, c='tab:purple',  label = '$\sigma_{Metro}$')
plt.title('Deviation from theory', fontsize=16)
plt.xlabel('T',fontsize=14)
plt.ylabel('$|U_{Teo}-U_{Simu}|$',fontsize=14)
plt.legend(fontsize=14)

plt.subplot(2,2,4)
plt.plot(T,abs(results2-e), c='tab:green', label = 'Gibbs')
plt.plot(T,uncertainties2, c='tab:purple', label = '$\sigma_{Gibbs}$')
plt.xlabel('T',fontsize=14)
plt.ylabel('$|U_{Teo}-U_{Simu}|$',fontsize=14)
plt.legend(fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# On the left there are shown the results of the simulations made with the two different algorithms together with the analytical prediction for the magnitude. Conversely, the plots on the right represent the deviation of the simulation compared to the associated error of the blocking average. It is clearly visible that the deviations tend to stay below one $\sigma$ with rare exceptions.
#
# The same statements hold for the other quantities

# %% [markdown]
# ### Heat capacity

# %%
import glob
import re
fig = plt.figure(figsize=(12,5))
fig.suptitle('$C$, heat capacity', fontsize=20)

plt.subplot(1,2,1)

T = np.linspace(0.2,3,num=58)
beta = 1/T
J = 1.0
Ns = 50
th = np.tanh(J/T)
thN= th**Ns
ch = 1/th
heat=((beta*J)**2)*(((1+thN+(Ns-1)*(th**2)+(Ns-1)*(ch**2)*thN)/(1+thN))-Ns*((th+ch*thN)/(1+thN))**2)
plt.plot(T, heat, label='Theory')
plt.title('Simulation', fontsize=16)
plt.xlabel('T', fontsize=14)
plt.ylabel('C', fontsize=14)

# Get a list of all the files that match the pattern temp*.dat in the folder containg this first simulation files
file_list = glob.glob("6.1/C/results/Metro/output.heat_*.dat")
file_list2 = glob.glob("6.1/C/results/Gibbs/output.heat_*.dat")

def extract_number(filename):
    return float(re.findall(r'\d+\.\d+', filename)[-1])

sorted_list = sorted(file_list, key=extract_number)
sorted_list2 = sorted(file_list2, key=extract_number)

results = []
uncertainties = []
temp = []

results2 = []
uncertainties2 = []
temp2=[]

for file in sorted_list:
    ene = np.loadtxt(file, usecols=(0, 2))
    err = np.loadtxt(file, usecols=(0, 3))
    results.append(ene[:,1][-1])
    uncertainties.append(err[:,1][-1])
    temp.append(float(file.split('_')[1].replace('.dat','')))
    
for file in sorted_list2:
    ene = np.loadtxt(file, usecols=(0, 2))
    err = np.loadtxt(file, usecols=(0, 3))
    results2.append(ene[:,1][-1])
    uncertainties2.append(err[:,1][-1])
    temp2.append(float(file.split('_')[1].replace('.dat','')))

    
plt.errorbar(temp, results, yerr=uncertainties,ls='--', elinewidth=1.5, marker='o', ms=4, mec='black', mew=0.5, label='Metropolis')
plt.errorbar(temp2, results2, yerr=uncertainties2,ls='--', elinewidth=1.5, marker='o', ms=4, mec='black', mew=0.5, label='Gibbs')

plt.legend(fontsize=14)

plt.subplot(2,2, 2)
plt.plot(T,abs(results-heat), c='tab:orange', label = 'Metropolis')
plt.plot(T,uncertainties, c='tab:purple',  label = '$\sigma_{Metro}$')
plt.title('Deviation from theory', fontsize=16)
plt.xlabel('T',fontsize=14)
plt.ylabel('$|C_{Teo}-C_{Simu}|$',fontsize=14)
plt.legend(fontsize=14)

plt.subplot(2,2,4)
plt.plot(T,abs(results2-heat), c='tab:green', label = 'Gibbs')
plt.plot(T,uncertainties2, c='tab:purple', label = '$\sigma_{Gibbs}$')
plt.xlabel('T',fontsize=14)
plt.ylabel('$|C_{Teo}-C_{Simu}|$',fontsize=14)
plt.legend(fontsize=14)
plt.tight_layout()
plt.show()

# %%
import glob
import re
fig = plt.figure(figsize=(12,5))
fig.suptitle('$M$, Magnetization at $h=0.02$', fontsize=20)


plt.subplot(1,2,1)

T = np.linspace(0.2,3,num=58)
h=0.02 #external field
b = 1/T

l1 = np.exp(b*J)*np.cosh(b*h)+np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))
l2 = np.exp(b*J)*np.cosh(b*h)-np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))
Z = l1**Ns + l2**Ns
M = (np.exp(b*J)*np.sinh(b*h)*((l1**(Ns-1))*(1+np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))) 
        + (l2**(Ns-1))*(1-np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J)))))/(Z)
plt.plot(T, M, label='Theory')
plt.title('Simulation', fontsize=16)
plt.xlabel('T', fontsize=14)
plt.ylabel('$M$', fontsize=14)

# Get a list of all the files that match the pattern temp*.dat in the folder containg this first simulation files
file_list = glob.glob("6.1/M/results/Metro/output.mag_*.dat")
file_list2 = glob.glob("6.1/M/results/Gibbs/output.mag_*.dat")

def extract_number(filename):
    return float(re.findall(r'\d+\.\d+', filename)[-1])

sorted_list = sorted(file_list, key=extract_number)
sorted_list2 = sorted(file_list2, key=extract_number)

results = []
uncertainties = []
temp = []

results2 = []
uncertainties2 = []
temp2=[]

for file in sorted_list:
    ene = np.loadtxt(file, usecols=(0, 2))
    err = np.loadtxt(file, usecols=(0, 3))
    results.append(ene[:,1][-1])
    uncertainties.append(err[:,1][-1])
    temp.append(float(file.split('_')[1].replace('.dat','')))
    
for file in sorted_list2:
    ene = np.loadtxt(file, usecols=(0, 2))
    err = np.loadtxt(file, usecols=(0, 3))
    results2.append(ene[:,1][-1])
    uncertainties2.append(err[:,1][-1])
    temp2.append(float(file.split('_')[1].replace('.dat','')))

    
plt.errorbar(temp, results, yerr=uncertainties,ls='--', elinewidth=1.5, marker='o', ms=4, mec='black', mew=0.5, label='Metropolis')
plt.errorbar(temp2, results2, yerr=uncertainties2,ls='--', elinewidth=1.5, marker='o', ms=4, mec='black', mew=0.5, label='Gibbs')

plt.legend(fontsize=14)

plt.subplot(2,2, 2)
plt.plot(T,abs(results-M), c='tab:orange', label = 'Metropolis')
plt.plot(T,uncertainties, c='tab:purple',  label = '$\sigma_{Metro}$')
plt.title('Deviation from theory', fontsize=16)
plt.xlabel('T', fontsize=14)
plt.ylabel('$|M_{Teo}-M_{Simu}|$', fontsize=14)
plt.legend(fontsize=14)

plt.subplot(2,2,4)
plt.plot(T,abs(results2-M), c='tab:green', label = 'Gibbs')
plt.plot(T,uncertainties2, c='tab:purple', label = '$\sigma_{Gibbs}$')
plt.xlabel('T',fontsize=14)
plt.ylabel('$|M_{Teo}-M_{Simu}|$',fontsize=14)
plt.legend(fontsize=14)
plt.tight_layout()
plt.show()

# %%
import glob
import re
fig = plt.figure(figsize=(12,5))
fig.suptitle('$\chi$, susceptibility',fontsize=20)

plt.subplot(1,2,1)

X = beta*np.exp(2*beta*J)*(1-thN)/(1+thN)
plt.plot(T, X, label ='Theory', lw=2)
plt.title('Simulation',fontsize=16)
plt.xlabel('T',fontsize=14)
plt.ylabel('$\chi$',fontsize=14)

# Get a list of all the files that match the pattern temp*.dat in the folder containg this first simulation files
file_list = glob.glob("6.1/CHI/results/Metro/output.chi_*.dat")
file_list2 = glob.glob("6.1/CHI/results/Gibbs/output.chi_*.dat")

def extract_number(filename):
    return float(re.findall(r'\d+\.\d+', filename)[-1])

sorted_list = sorted(file_list, key=extract_number)
sorted_list2 = sorted(file_list2, key=extract_number)

results = []
uncertainties = []
temp = []

results2 = []
uncertainties2 = []
temp2=[]

for file in sorted_list:
    ene = np.loadtxt(file, usecols=(0, 2))
    err = np.loadtxt(file, usecols=(0, 3))
    results.append(ene[:,1][-1])
    uncertainties.append(err[:,1][-1])
    temp.append(float(file.split('_')[1].replace('.dat','')))
    
for file in sorted_list2:
    ene = np.loadtxt(file, usecols=(0, 2))
    err = np.loadtxt(file, usecols=(0, 3))
    results2.append(ene[:,1][-1])
    uncertainties2.append(err[:,1][-1])
    temp2.append(float(file.split('_')[1].replace('.dat','')))

    
plt.errorbar(temp, results, yerr=uncertainties,ls='--', elinewidth=1.5, marker='o', ms=4, mec='black', mew=0.5, label='Metropolis')
plt.errorbar(temp2, results2, yerr=uncertainties2,ls='--', elinewidth=1.5, marker='o', ms=4, mec='black', mew=0.5, label='Gibbs')

plt.legend(fontsize=14)

plt.subplot(2,2, 2)
plt.plot(T,abs(results-X), c='tab:orange', label = 'Metropolis')
plt.plot(T,uncertainties, c='tab:purple',  label = '$\sigma_{Metro}$')
plt.title('Deviation from theory',fontsize=16)
plt.xlabel('T',fontsize=14)
plt.ylabel('$|\chi_{Teo}-\chi_{Simu}|$',fontsize=14)
plt.legend(fontsize=14)

plt.subplot(2,2,4)
plt.plot(T,abs(results2-X), c='tab:green', label = 'Gibbs')
plt.plot(T,uncertainties2, c='tab:purple', label = '$\sigma_{Gibbs}$')
plt.xlabel('T',fontsize=14)
plt.ylabel('$|\chi_{Teo}-\chi_{Simu}|$',fontsize=14)
plt.legend(fontsize=14)
plt.tight_layout()
plt.show()
